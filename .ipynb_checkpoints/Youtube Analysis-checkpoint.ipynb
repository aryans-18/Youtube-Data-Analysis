# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyCU0irwez2sVolZF8FHSl6O-5IFGi4EkLg'
channel_ids = [
               'UCnz-ZXXER4jOvuED5trXfEA', #Techfq
               'UCvEKHATlVq84hm1jduTYm8g', #striver
               'UCldyi11QYNXYXiLjVbyw5dA', #Codehelp by Babbar
               'UC58_wzhvJta3hDSPvRLDAqg', #Anuj Bhaiya
               'UC81Q2wnuk5KqOFVgAbq4nUw' #Fraz
            ]
youtube = build('youtube','v3',developerKey = api_key)

# %%
def get_channel_stats(youtube , channel_ids):
    all_data = []
    
    request = youtube.channels().list(part = 'snippet,contentDetails,statistics',id =','. join(channel_ids))
    response = request.execute()

    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    Playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads']
                   )
        
        all_data.append(data)
        
    return all_data

# %%
channel_statistics = get_channel_stats(youtube , channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#            Channel_name Subscribers     Views Total_videos  \
# 0           Anuj Bhaiya      446000  32447211          215
# 1               Striver      176000   6609342           77
# 2  CodeHelp - by Babbar      444000  43289684          306
# 3               techTFQ      232000  11802354           95
# 4                  Fraz      341000  25474703          418
#
#                 Playlist_id
# 0  UU58_wzhvJta3hDSPvRLDAqg
# 1  UUvEKHATlVq84hm1jduTYm8g
# 2  UUldyi11QYNXYXiLjVbyw5dA
# 3  UUnz-ZXXER4jOvuED5trXfEA
# 4  UU81Q2wnuk5KqOFVgAbq4nUw

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(x = 'Channel_name', y = 'Subscribers' , data = channel_data)
# Out:
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.set(rc={'figure.figsize':(10,4)})
ax = sns.barplot(x = 'Channel_name', y = 'Views' , data = channel_data)
# Out:
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.set(rc={'figure.figsize':(10,4)})
ax = sns.barplot(x = 'Channel_name', y = 'Total_videos' , data = channel_data)
# Out:
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Function to get video ids

# %%
channel_data
# Out:
#            Channel_name  Subscribers     Views  Total_videos  \
# 0           Anuj Bhaiya       446000  32447211           215
# 1               Striver       176000   6609342            77
# 2  CodeHelp - by Babbar       444000  43289684           306
# 3               techTFQ       232000  11802354            95
# 4                  Fraz       341000  25474703           418
#
#                 Playlist_id
# 0  UU58_wzhvJta3hDSPvRLDAqg
# 1  UUvEKHATlVq84hm1jduTYm8g
# 2  UUldyi11QYNXYXiLjVbyw5dA
# 3  UUnz-ZXXER4jOvuED5trXfEA
# 4  UU81Q2wnuk5KqOFVgAbq4nUw

# %%
playlist_id = channel_data.loc[channel_data['Channel_name'] == 'techTFQ','Playlist_id'].iloc[0]

# %%
playlist_id
# Out:
# 'UUnz-ZXXER4jOvuED5trXfEA'

# %%
def get_video_ids(youtube , playlist_id):

    request = youtube.playlistItems().list(
        part = 'contentDetails',
        playlistId = playlist_id,
        maxResults = 50)
    response = request.execute()

    video_ids = []
    for i in range (len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])

    next_page_taken = response.get('nextPageTaken')
    more_pages = True

    while more_pages:
        if next_page_taken is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                part = 'contentDetails',
                playlistId = playlist_id,
                maxResults = 50,
                pageToken = next_page_token)
            response = request.execute()
              
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])

            next_page_token = response.get('nextPageToken')
            

    return video_ids

# %%
video_ids = get_video_ids(youtube,playlist_id)

# %%
video_ids
# Out:
# ['oedv5lR3w_g',
#  'HiscSRv7zWk',
#  'PLN28d0PoFU',
#  'GxmrInUIMAE',
#  'D0-Qy7yk5TQ',
#  'GHtX0QXfi6g',
#  '0QcEqFrhb_Y',
#  'smztq8sRAhk',
#  '7skZzocEU6c',
#  'LZGaRcDxj8I',
#  'rBPQ5fg_kiY',
#  'hvwltYazuQo',
#  'a-hFbr-4VQQ',
#  'pMNcPLc9Z7c',
#  'zZKb8FQRShs',
#  'jS5_hjFgfzA',
#  '6UAU79FNBjQ',
#  'ZwFfiadQB3k',
#  'Det4ZjBSe3M',
#  'xUsY2jWQa1w',
#  'ueOUSjdAZY8',
#  '90iK6gGvG_g',
#  'hsaPfEvForM',
#  'jb8XlF2dkoY',
#  'WhkNQ3g0U64',
#  '_suB8xV9aPc',
#  'dWHSt0BVlv0',
#  'xJVWL7eMir0',
#  'h48xzQR3wNQ',
#  'S5gX-LLAZIM',
#  'LNlzx-YX8rI',
#  'WzkBZ0byoYE',
#  'weCZ1WynbMI',
#  '3dOxGYkpVbE',
#  '9dLXZrw6nac',
#  'i3xK7Nc414Q',
#  'H7YMumanHBA',
#  '4p-G7fGhqRk',
#  'yLR1w4tZ36I',
#  '-DiOp9vAEuM',
#  'O1o9m9T1c3k',
#  '7hZYh9qXxe4',
#  'aE623ff7zkM',
#  'eXJGjbDo5KY',
#  'O52sweYbCyI',
#  'cLSxasHg9WY',
#  'l6XhSFAyvO0',
#  'nJIEIzF7tDw',
#  'RehbnzKHS28',
#  '0OQJDd3QqQM']

# %% [markdown]
# Function to get video details

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []


    for i in range(0, len(video_ids), 50):
       
        video_id_batch = video_ids[i:i + 50]
        
        request = youtube.videos().list(
            part='snippet,statistics',
            id=','.join(video_id_batch)
        )
        
       
        response = request.execute()

        
        for video in response['items']:
            
            video_stats = {
                'Title': video['snippet']['title'],
                'Published_date': video['snippet']['publishedAt'],
                'Views': video['statistics']['viewCount'],
                'Likes': video['statistics']['likeCount'],
                'Comments': video['statistics']['commentCount']
            }
            
            
            if 'dislikeCount' in video['statistics']:
                video_stats['Dislikes'] = video['statistics']['dislikeCount']
            else:
                video_stats['Dislikes'] = 0  # Set to 0 if 'dislikeCount' is missing

            
            all_video_stats.append(video_stats)

    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_details
# Out:
# [{'Title': 'Courses You Can Take To Get Into Data Analytics',
#   'Published_date': '2023-09-02T13:00:12Z',
#   'Views': '15274',
#   'Likes': '353',
#   'Comments': '63',
#   'Dislikes': 0},
#  {'Title': 'Solving a Real SQL Interview Problem | Job Vacancies SQL Query',
#   'Published_date': '2023-08-25T13:00:09Z',
#   'Views': '27759',
#   'Likes': '1074',
#   'Comments': '109',
#   'Dislikes': 0},
#  {'Title': 'Python Bootcamp for Beginners | Python Course | Live Training',
#   'Published_date': '2023-08-20T08:17:01Z',
#   'Views': '3797',
#   'Likes': '154',
#   'Comments': '28',
#   'Dislikes': 0},
#  {'Title': 'SQL Data Analytics Project (PART 3) | Data Analyst Portfolio Project',
#   'Published_date': '2023-08-19T13:14:46Z',
#   'Views': '6925',
#   'Likes': '237',
#   'Comments': '33',
#   'Dislikes': 0},
#  {'Title': 'SQL Data Analytics Project (PART 2) | Data Analyst Portfolio Project',
#   'Published_date': '2023-08-06T13:00:08Z',
#   'Views': '11067',
#   'Likes': '347',
#   'Comments': '45',
#   'Dislikes': 0},
#  {'Title': 'SQL Data Analytics Project (PART 1) | Data Analyst Portfolio Project',
#   'Published_date': '2023-08-04T13:00:11Z',
#   'Views': '42431',
#   'Likes': '1501',
#   'Comments': '132',
#   'Dislikes': 0},
#  {'Title': 'Learn SQL from me | Live SQL Training | SQL Bootcamp',
#   'Published_date': '2023-05-25T14:35:13Z',
#   'Views': '22223',
#   'Likes': '622',
#   'Comments': '179',
#   'Dislikes': 0},
#  {'Title': 'Learn Python here | Learn Python Programming here',
#   'Published_date': '2023-05-16T13:45:59Z',
#   'Views': '14530',
#   'Likes': '268',
#   'Comments': '23',
#   'Dislikes': 0},
#  {'Title': 'Solving a Complex SQL Interview problem | Practice SQL Queries',
#   'Published_date': '2023-03-21T13:00:12Z',
#   'Views': '36489',
#   'Likes': '1023',
#   'Comments': '105',
#   'Dislikes': 0},
#  {'Title': 'REAL SQL Interview Problem | Hierarchical data in SQL',
#   'Published_date': '2023-03-14T13:00:09Z',
#   'Views': '20144',
#   'Likes': '770',
#   'Comments': '63',
#   'Dislikes': 0},
#  {'Title': 'Complete guide to Database Normalization in SQL',
#   'Published_date': '2023-03-07T13:00:07Z',
#   'Views': '57580',
#   'Likes': '2577',
#   'Comments': '243',
#   'Dislikes': 0},
#  {'Title': 'SQL Live class on Lighthall | Learn SQL from Basic to Advance in SQL Bootcamp',
#   'Published_date': '2023-01-26T07:00:07Z',
#   'Views': '12439',
#   'Likes': '250',
#   'Comments': '154',
#   'Dislikes': 0},
#  {'Title': 'How to learn SQL for free | Roadmap to learning SQL',
#   'Published_date': '2022-12-28T13:00:10Z',
#   'Views': '423502',
#   'Likes': '13079',
#   'Comments': '399',
#   'Dislikes': 0},
#  {'Title': 'Solving an SQL Interview Problem',
#   'Published_date': '2022-12-18T13:39:48Z',
#   'Views': '36374',
#   'Likes': '1473',
#   'Comments': '18',
#   'Dislikes': 0},
#  {'Title': 'Solving SQL Interview Query | Find Tree Node type using SQL',
#   'Published_date': '2022-12-12T13:30:15Z',
#   'Views': '20732',
#   'Likes': '889',
#   'Comments': '52',
#   'Dislikes': 0},
#  {'Title': 'Solving SQL Interview Query for Data Analyst asked by a Product based company',
#   'Published_date': '2022-12-07T13:25:28Z',
#   'Views': '409381',
#   'Likes': '9467',
#   'Comments': '270',
#   'Dislikes': 0},
#  {'Title': 'Solving a tricky SQL Interview Query',
#   'Published_date': '2022-11-21T13:00:04Z',
#   'Views': '44314',
#   'Likes': '1525',
#   'Comments': '123',
#   'Dislikes': 0},
#  {'Title': 'SQL Interview Query for Data Analyst',
#   'Published_date': '2022-11-14T13:00:17Z',
#   'Views': '49276',
#   'Likes': '1774',
#   'Comments': '68',
#   'Dislikes': 0},
#  {'Title': 'Solving a Complex SQL Interview Problem | Find the Most Modified File Extension',
#   'Published_date': '2022-10-31T13:00:16Z',
#   'Views': '25597',
#   'Likes': '988',
#   'Comments': '76',
#   'Dislikes': 0},
#  {'Title': 'SQL JOINS Interview Question | What does different SQL Joins return?',
#   'Published_date': '2022-10-24T13:30:12Z',
#   'Views': '250474',
#   'Likes': '7768',
#   'Comments': '385',
#   'Dislikes': 0},
#  {'Title': 'Google SQL Interview Problem | Solving SQL Interview Query',
#   'Published_date': '2022-10-10T13:00:28Z',
#   'Views': '33977',
#   'Likes': '1276',
#   'Comments': '128',
#   'Dislikes': 0},
#  {'Title': 'SQL Interview Problem asked by Product Based Company | Solving SQL Interview Query',
#   'Published_date': '2022-10-05T13:13:21Z',
#   'Views': '55291',
#   'Likes': '2109',
#   'Comments': '135',
#   'Dislikes': 0},
#  {'Title': 'How to become a Data Analyst FASTER ?',
#   'Published_date': '2022-09-30T13:44:54Z',
#   'Views': '95048',
#   'Likes': '4020',
#   'Comments': '190',
#   'Dislikes': 0},
#  {'Title': 'Tricky SQL Interview Query | Practice Solving SQL Interview Queries',
#   'Published_date': '2022-09-22T13:00:26Z',
#   'Views': '28362',
#   'Likes': '869',
#   'Comments': '99',
#   'Dislikes': 0},
#  {'Title': 'Solving SQL Interview Query using a "VERY IMPORTANT SQL concept"',
#   'Published_date': '2022-09-19T13:00:17Z',
#   'Views': '96196',
#   'Likes': '2343',
#   'Comments': '177',
#   'Dislikes': 0},
#  {'Title': 'Solving SQL Interview Query | SQL Problem by Service based company',
#   'Published_date': '2022-09-16T13:00:32Z',
#   'Views': '29565',
#   'Likes': '1101',
#   'Comments': '73',
#   'Dislikes': 0},
#  {'Title': 'Practice SQL Interview Query | Big 4 Interview Question',
#   'Published_date': '2022-09-12T13:00:33Z',
#   'Views': '82124',
#   'Likes': '3011',
#   'Comments': '172',
#   'Dislikes': 0},
#  {'Title': 'Solving SQL Interview Query | Ungroup given input data | FAANG Interview Query',
#   'Published_date': '2022-09-08T13:00:36Z',
#   'Views': '35009',
#   'Likes': '1049',
#   'Comments': '81',
#   'Dislikes': 0},
#  {'Title': 'How to remove Duplicate Data in SQL | SQL Query to remove duplicate',
#   'Published_date': '2022-09-02T13:29:46Z',
#   'Views': '226084',
#   'Likes': '5568',
#   'Comments': '234',
#   'Dislikes': 0},
#  {'Title': 'Solving Complex SQL Query from HackerRank | SQL Interview Query',
#   'Published_date': '2022-08-10T13:56:09Z',
#   'Views': '59899',
#   'Likes': '1519',
#   'Comments': '144',
#   'Dislikes': 0},
#  {'Title': 'Data Analyst vs Business Analyst | What should you choose?',
#   'Published_date': '2022-07-26T12:45:01Z',
#   'Views': '27297',
#   'Likes': '1202',
#   'Comments': '110',
#   'Dislikes': 0},
#  {'Title': 'Materialized View in SQL | Faster SQL Queries using Materialized Views',
#   'Published_date': '2022-07-07T13:04:22Z',
#   'Views': '62231',
#   'Likes': '1681',
#   'Comments': '171',
#   'Dislikes': 0},
#  {'Title': 'Learn SQL the right way | SQL Live Training | Learn SQL from me',
#   'Published_date': '2022-06-28T14:30:13Z',
#   'Views': '30086',
#   'Likes': '590',
#   'Comments': '189',
#   'Dislikes': 0},
#  {'Title': 'SQL Interview Assignment Queries | REAL SQL Assignment given in Interview Part 2 (Query Solution)',
#   'Published_date': '2022-06-21T14:10:42Z',
#   'Views': '23091',
#   'Likes': '570',
#   'Comments': '49',
#   'Dislikes': 0},
#  {'Title': 'SQL Interview Assignment Queries | REAL SQL Assignment given in Interview Part 1 (Problem Statement)',
#   'Published_date': '2022-06-17T13:30:02Z',
#   'Views': '18990',
#   'Likes': '569',
#   'Comments': '80',
#   'Dislikes': 0},
#  {'Title': 'REAL SQL Interview Question | Complex SQL Interview Query and Solution',
#   'Published_date': '2022-06-03T13:35:34Z',
#   'Views': '56798',
#   'Likes': '1397',
#   'Comments': '112',
#   'Dislikes': 0},
#  {'Title': 'Top 10 Tips for JOB Interview | Tips for Job Interview',
#   'Published_date': '2022-05-25T13:00:15Z',
#   'Views': '14657',
#   'Likes': '574',
#   'Comments': '45',
#   'Dislikes': 0},
#  {'Title': 'Solving SQL Query | Rows to Column in SQL',
#   'Published_date': '2022-05-18T13:21:24Z',
#   'Views': '116169',
#   'Likes': '3044',
#   'Comments': '160',
#   'Dislikes': 0},
#  {'Title': 'Procedure Tutorial in SQL | SQL Stored Procedure | Procedure in SQL',
#   'Published_date': '2022-05-01T03:28:03Z',
#   'Views': '169932',
#   'Likes': '3358',
#   'Comments': '180',
#   'Dislikes': 0},
#  {'Title': 'my Live SQL Course Announcement #shorts',
#   'Published_date': '2022-04-05T08:50:58Z',
#   'Views': '20000',
#   'Likes': '872',
#   'Comments': '85',
#   'Dislikes': 0},
#  {'Title': 'Best Online SQL Course to practically learn and practice SQL',
#   'Published_date': '2022-03-30T14:35:14Z',
#   'Views': '29502',
#   'Likes': '548',
#   'Comments': '118',
#   'Dislikes': 0},
#  {'Title': 'Recursive SQL Queries Tutorial | Learn to write SQL Queries using Recursion',
#   'Published_date': '2022-03-23T15:36:43Z',
#   'Views': '130249',
#   'Likes': '3429',
#   'Comments': '250',
#   'Dislikes': 0},
#  {'Title': 'Solving SQL Interview Queries | Tricky SQL Interview Queries',
#   'Published_date': '2022-03-16T14:27:54Z',
#   'Views': '204215',
#   'Likes': '5213',
#   'Comments': '407',
#   'Dislikes': 0},
#  {'Title': 'How to learn SQL | Step by Step Guide on how to learn SQL',
#   'Published_date': '2022-03-02T13:27:49Z',
#   'Views': '129614',
#   'Likes': '4622',
#   'Comments': '340',
#   'Dislikes': 0},
#  {'Title': 'ANSI vs Non ANSI Joins in SQL | SQL Query Writing using ANSI and Non ANSI method',
#   'Published_date': '2022-02-23T13:58:34Z',
#   'Views': '30592',
#   'Likes': '682',
#   'Comments': '84',
#   'Dislikes': 0},
#  {'Title': 'SQL Views Tutorial | VIEWS in SQL Complete Tutorial',
#   'Published_date': '2022-02-15T13:00:16Z',
#   'Views': '173998',
#   'Likes': '3868',
#   'Comments': '334',
#   'Dislikes': 0},
#  {'Title': 'Practice Writing SQL Queries on StrataScratch | How to Solve SQL Queries',
#   'Published_date': '2022-02-08T13:59:30Z',
#   'Views': '129888',
#   'Likes': '3311',
#   'Comments': '187',
#   'Dislikes': 0},
#  {'Title': 'Subquery in SQL | Correlated Subquery + Complete SQL Subqueries Tutorial',
#   'Published_date': '2022-02-01T13:00:24Z',
#   'Views': '704494',
#   'Likes': '16387',
#   'Comments': '995',
#   'Dislikes': 0},
#  {'Title': 'SQL JOINS Tutorial for beginners | Practice SQL Queries using JOINS - Part 2',
#   'Published_date': '2022-01-14T13:00:30Z',
#   'Views': '210389',
#   'Likes': '6956',
#   'Comments': '494',
#   'Dislikes': 0},
#  {'Title': 'SQL JOINS Tutorial for beginners | Practice SQL Queries using JOINS - Part 1',
#   'Published_date': '2022-01-06T13:00:00Z',
#   'Views': '587569',
#   'Likes': '14362',
#   'Comments': '933',
#   'Dislikes': 0}]

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                 Title        Published_date  \
# 0     Courses You Can Take To Get Into Data Analytics  2023-09-02T13:00:12Z
# 1   Solving a Real SQL Interview Problem | Job Vac...  2023-08-25T13:00:09Z
# 2   Python Bootcamp for Beginners | Python Course ...  2023-08-20T08:17:01Z
# 3   SQL Data Analytics Project (PART 3) | Data Ana...  2023-08-19T13:14:46Z
# 4   SQL Data Analytics Project (PART 2) | Data Ana...  2023-08-06T13:00:08Z
# 5   SQL Data Analytics Project (PART 1) | Data Ana...  2023-08-04T13:00:11Z
# 6   Learn SQL from me | Live SQL Training | SQL Bo...  2023-05-25T14:35:13Z
# 7   Learn Python here | Learn Python Programming here  2023-05-16T13:45:59Z
# 8   Solving a Complex SQL Interview problem | Prac...  2023-03-21T13:00:12Z
# 9   REAL SQL Interview Problem | Hierarchical data...  2023-03-14T13:00:09Z
# 10    Complete guide to Database Normalization in SQL  2023-03-07T13:00:07Z
# 11  SQL Live class on Lighthall | Learn SQL from B...  2023-01-26T07:00:07Z
# 12  How to learn SQL for free | Roadmap to learnin...  2022-12-28T13:00:10Z
# 13                   Solving an SQL Interview Problem  2022-12-18T13:39:48Z
# 14  Solving SQL Interview Query | Find Tree Node t...  2022-12-12T13:30:15Z
# 15  Solving SQL Interview Query for Data Analyst a...  2022-12-07T13:25:28Z
# 16               Solving a tricky SQL Interview Query  2022-11-21T13:00:04Z
# 17               SQL Interview Query for Data Analyst  2022-11-14T13:00:17Z
# 18  Solving a Complex SQL Interview Problem | Find...  2022-10-31T13:00:16Z
# 19  SQL JOINS Interview Question | What does diffe...  2022-10-24T13:30:12Z
# 20  Google SQL Interview Problem | Solving SQL Int...  2022-10-10T13:00:28Z
# 21  SQL Interview Problem asked by Product Based C...  2022-10-05T13:13:21Z
# 22              How to become a Data Analyst FASTER ?  2022-09-30T13:44:54Z
# 23  Tricky SQL Interview Query | Practice Solving ...  2022-09-22T13:00:26Z
# 24  Solving SQL Interview Query using a "VERY IMPO...  2022-09-19T13:00:17Z
# 25  Solving SQL Interview Query | SQL Problem by S...  2022-09-16T13:00:32Z
# 26  Practice SQL Interview Query | Big 4 Interview...  2022-09-12T13:00:33Z
# 27  Solving SQL Interview Query | Ungroup given in...  2022-09-08T13:00:36Z
# 28  How to remove Duplicate Data in SQL | SQL Quer...  2022-09-02T13:29:46Z
# 29  Solving Complex SQL Query from HackerRank | SQ...  2022-08-10T13:56:09Z
# 30  Data Analyst vs Business Analyst | What should...  2022-07-26T12:45:01Z
# 31  Materialized View in SQL | Faster SQL Queries ...  2022-07-07T13:04:22Z
# 32  Learn SQL the right way | SQL Live Training | ...  2022-06-28T14:30:13Z
# 33  SQL Interview Assignment Queries | REAL SQL As...  2022-06-21T14:10:42Z
# 34  SQL Interview Assignment Queries | REAL SQL As...  2022-06-17T13:30:02Z
# 35  REAL SQL Interview Question | Complex SQL Inte...  2022-06-03T13:35:34Z
# 36  Top 10 Tips for JOB Interview | Tips for Job I...  2022-05-25T13:00:15Z
# 37          Solving SQL Query | Rows to Column in SQL  2022-05-18T13:21:24Z
# 38  Procedure Tutorial in SQL | SQL Stored Procedu...  2022-05-01T03:28:03Z
# 39            my Live SQL Course Announcement #shorts  2022-04-05T08:50:58Z
# 40  Best Online SQL Course to practically learn an...  2022-03-30T14:35:14Z
# 41  Recursive SQL Queries Tutorial | Learn to writ...  2022-03-23T15:36:43Z
# 42  Solving SQL Interview Queries | Tricky SQL Int...  2022-03-16T14:27:54Z
# 43  How to learn SQL | Step by Step Guide on how t...  2022-03-02T13:27:49Z
# 44  ANSI vs Non ANSI Joins in SQL | SQL Query Writ...  2022-02-23T13:58:34Z
# 45  SQL Views Tutorial | VIEWS in SQL Complete Tut...  2022-02-15T13:00:16Z
# 46  Practice Writing SQL Queries on StrataScratch ...  2022-02-08T13:59:30Z
# 47  Subquery in SQL | Correlated Subquery + Comple...  2022-02-01T13:00:24Z
# 48  SQL JOINS Tutorial for beginners | Practice SQ...  2022-01-14T13:00:30Z
# 49  SQL JOINS Tutorial for beginners | Practice SQ...  2022-01-06T13:00:00Z
#
#      Views  Likes Comments  Dislikes
# 0    15274    353       63         0
# 1    27759   1074      109         0
# 2     3797    154       28         0
# 3     6925    237       33         0
# 4    11067    347       45         0
# 5    42431   1501      132         0
# 6    22223    622      179         0
# 7    14530    268       23         0
# 8    36489   1023      105         0
# 9    20144    770       63         0
# 10   57580   2577      243         0
# 11   12439    250      154         0
# 12  423502  13079      399         0
# 13   36374   1473       18         0
# 14   20732    889       52         0
# 15  409381   9467      270         0
# 16   44314   1525      123         0
# 17   49276   1774       68         0
# 18   25597    988       76         0
# 19  250474   7768      385         0
# 20   33977   1276      128         0
# 21   55291   2109      135         0
# 22   95048   4020      190         0
# 23   28362    869       99         0
# 24   96196   2343      177         0
# 25   29565   1101       73         0
# 26   82124   3011      172         0
# 27   35009   1049       81         0
# 28  226084   5568      234         0
# 29   59899   1519      144         0
# 30   27297   1202      110         0
# 31   62231   1681      171         0
# 32   30086    590      189         0
# 33   23091    570       49         0
# 34   18990    569       80         0
# 35   56798   1397      112         0
# 36   14657    574       45         0
# 37  116169   3044      160         0
# 38  169932   3358      180         0
# 39   20000    872       85         0
# 40   29502    548      118         0
# 41  130249   3429      250         0
# 42  204215   5213      407         0
# 43  129614   4622      340         0
# 44   30592    682       84         0
# 45  173998   3868      334         0
# 46  129888   3311      187         0
# 47  704494  16387      995         0
# 48  210389   6956      494         0
# 49  587569  14362      933         0

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date

video_data['Views'] = pd.to_numeric(video_data['Views']) 
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Dislikes'] = pd.to_numeric(video_data['Dislikes'])
video_data['Views'] = pd.to_numeric(video_data['Views'])

# %%
video_data
# Out:
#                                                 Title Published_date   Views  \
# 0     Courses You Can Take To Get Into Data Analytics     2023-09-02   15274
# 1   Solving a Real SQL Interview Problem | Job Vac...     2023-08-25   27759
# 2   Python Bootcamp for Beginners | Python Course ...     2023-08-20    3797
# 3   SQL Data Analytics Project (PART 3) | Data Ana...     2023-08-19    6925
# 4   SQL Data Analytics Project (PART 2) | Data Ana...     2023-08-06   11067
# 5   SQL Data Analytics Project (PART 1) | Data Ana...     2023-08-04   42431
# 6   Learn SQL from me | Live SQL Training | SQL Bo...     2023-05-25   22223
# 7   Learn Python here | Learn Python Programming here     2023-05-16   14530
# 8   Solving a Complex SQL Interview problem | Prac...     2023-03-21   36489
# 9   REAL SQL Interview Problem | Hierarchical data...     2023-03-14   20144
# 10    Complete guide to Database Normalization in SQL     2023-03-07   57580
# 11  SQL Live class on Lighthall | Learn SQL from B...     2023-01-26   12439
# 12  How to learn SQL for free | Roadmap to learnin...     2022-12-28  423502
# 13                   Solving an SQL Interview Problem     2022-12-18   36374
# 14  Solving SQL Interview Query | Find Tree Node t...     2022-12-12   20732
# 15  Solving SQL Interview Query for Data Analyst a...     2022-12-07  409381
# 16               Solving a tricky SQL Interview Query     2022-11-21   44314
# 17               SQL Interview Query for Data Analyst     2022-11-14   49276
# 18  Solving a Complex SQL Interview Problem | Find...     2022-10-31   25597
# 19  SQL JOINS Interview Question | What does diffe...     2022-10-24  250474
# 20  Google SQL Interview Problem | Solving SQL Int...     2022-10-10   33977
# 21  SQL Interview Problem asked by Product Based C...     2022-10-05   55291
# 22              How to become a Data Analyst FASTER ?     2022-09-30   95048
# 23  Tricky SQL Interview Query | Practice Solving ...     2022-09-22   28362
# 24  Solving SQL Interview Query using a "VERY IMPO...     2022-09-19   96196
# 25  Solving SQL Interview Query | SQL Problem by S...     2022-09-16   29565
# 26  Practice SQL Interview Query | Big 4 Interview...     2022-09-12   82124
# 27  Solving SQL Interview Query | Ungroup given in...     2022-09-08   35009
# 28  How to remove Duplicate Data in SQL | SQL Quer...     2022-09-02  226084
# 29  Solving Complex SQL Query from HackerRank | SQ...     2022-08-10   59899
# 30  Data Analyst vs Business Analyst | What should...     2022-07-26   27297
# 31  Materialized View in SQL | Faster SQL Queries ...     2022-07-07   62231
# 32  Learn SQL the right way | SQL Live Training | ...     2022-06-28   30086
# 33  SQL Interview Assignment Queries | REAL SQL As...     2022-06-21   23091
# 34  SQL Interview Assignment Queries | REAL SQL As...     2022-06-17   18990
# 35  REAL SQL Interview Question | Complex SQL Inte...     2022-06-03   56798
# 36  Top 10 Tips for JOB Interview | Tips for Job I...     2022-05-25   14657
# 37          Solving SQL Query | Rows to Column in SQL     2022-05-18  116169
# 38  Procedure Tutorial in SQL | SQL Stored Procedu...     2022-05-01  169932
# 39            my Live SQL Course Announcement #shorts     2022-04-05   20000
# 40  Best Online SQL Course to practically learn an...     2022-03-30   29502
# 41  Recursive SQL Queries Tutorial | Learn to writ...     2022-03-23  130249
# 42  Solving SQL Interview Queries | Tricky SQL Int...     2022-03-16  204215
# 43  How to learn SQL | Step by Step Guide on how t...     2022-03-02  129614
# 44  ANSI vs Non ANSI Joins in SQL | SQL Query Writ...     2022-02-23   30592
# 45  SQL Views Tutorial | VIEWS in SQL Complete Tut...     2022-02-15  173998
# 46  Practice Writing SQL Queries on StrataScratch ...     2022-02-08  129888
# 47  Subquery in SQL | Correlated Subquery + Comple...     2022-02-01  704494
# 48  SQL JOINS Tutorial for beginners | Practice SQ...     2022-01-14  210389
# 49  SQL JOINS Tutorial for beginners | Practice SQ...     2022-01-06  587569
#
#     Likes Comments  Dislikes
# 0     353       63         0
# 1    1074      109         0
# 2     154       28         0
# 3     237       33         0
# 4     347       45         0
# 5    1501      132         0
# 6     622      179         0
# 7     268       23         0
# 8    1023      105         0
# 9     770       63         0
# 10   2577      243         0
# 11    250      154         0
# 12  13079      399         0
# 13   1473       18         0
# 14    889       52         0
# 15   9467      270         0
# 16   1525      123         0
# 17   1774       68         0
# 18    988       76         0
# 19   7768      385         0
# 20   1276      128         0
# 21   2109      135         0
# 22   4020      190         0
# 23    869       99         0
# 24   2343      177         0
# 25   1101       73         0
# 26   3011      172         0
# 27   1049       81         0
# 28   5568      234         0
# 29   1519      144         0
# 30   1202      110         0
# 31   1681      171         0
# 32    590      189         0
# 33    570       49         0
# 34    569       80         0
# 35   1397      112         0
# 36    574       45         0
# 37   3044      160         0
# 38   3358      180         0
# 39    872       85         0
# 40    548      118         0
# 41   3429      250         0
# 42   5213      407         0
# 43   4622      340         0
# 44    682       84         0
# 45   3868      334         0
# 46   3311      187         0
# 47  16387      995         0
# 48   6956      494         0
# 49  14362      933         0

# %%
top10_videos = video_data.sort_values(by = 'Views' , ascending = False).head(10)

# %%
top10_videos
# Out:
#                                                 Title Published_date   Views  \
# 47  Subquery in SQL | Correlated Subquery + Comple...     2022-02-01  704494
# 49  SQL JOINS Tutorial for beginners | Practice SQ...     2022-01-06  587569
# 12  How to learn SQL for free | Roadmap to learnin...     2022-12-28  423502
# 15  Solving SQL Interview Query for Data Analyst a...     2022-12-07  409381
# 19  SQL JOINS Interview Question | What does diffe...     2022-10-24  250474
# 28  How to remove Duplicate Data in SQL | SQL Quer...     2022-09-02  226084
# 48  SQL JOINS Tutorial for beginners | Practice SQ...     2022-01-14  210389
# 42  Solving SQL Interview Queries | Tricky SQL Int...     2022-03-16  204215
# 45  SQL Views Tutorial | VIEWS in SQL Complete Tut...     2022-02-15  173998
# 38  Procedure Tutorial in SQL | SQL Stored Procedu...     2022-05-01  169932
#
#     Likes Comments  Dislikes
# 47  16387      995         0
# 49  14362      933         0
# 12  13079      399         0
# 15   9467      270         0
# 19   7768      385         0
# 28   5568      234         0
# 48   6956      494         0
# 42   5213      407         0
# 45   3868      334         0
# 38   3358      180         0

# %%
ax1 = sns.barplot(x = 'Views', y = 'Title' , data = top10_videos)
# Out:
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
video_data
# Out:
#                                                 Title Published_date   Views  \
# 0     Courses You Can Take To Get Into Data Analytics     2023-09-02   15274
# 1   Solving a Real SQL Interview Problem | Job Vac...     2023-08-25   27759
# 2   Python Bootcamp for Beginners | Python Course ...     2023-08-20    3797
# 3   SQL Data Analytics Project (PART 3) | Data Ana...     2023-08-19    6925
# 4   SQL Data Analytics Project (PART 2) | Data Ana...     2023-08-06   11067
# 5   SQL Data Analytics Project (PART 1) | Data Ana...     2023-08-04   42431
# 6   Learn SQL from me | Live SQL Training | SQL Bo...     2023-05-25   22223
# 7   Learn Python here | Learn Python Programming here     2023-05-16   14530
# 8   Solving a Complex SQL Interview problem | Prac...     2023-03-21   36489
# 9   REAL SQL Interview Problem | Hierarchical data...     2023-03-14   20144
# 10    Complete guide to Database Normalization in SQL     2023-03-07   57580
# 11  SQL Live class on Lighthall | Learn SQL from B...     2023-01-26   12439
# 12  How to learn SQL for free | Roadmap to learnin...     2022-12-28  423502
# 13                   Solving an SQL Interview Problem     2022-12-18   36374
# 14  Solving SQL Interview Query | Find Tree Node t...     2022-12-12   20732
# 15  Solving SQL Interview Query for Data Analyst a...     2022-12-07  409381
# 16               Solving a tricky SQL Interview Query     2022-11-21   44314
# 17               SQL Interview Query for Data Analyst     2022-11-14   49276
# 18  Solving a Complex SQL Interview Problem | Find...     2022-10-31   25597
# 19  SQL JOINS Interview Question | What does diffe...     2022-10-24  250474
# 20  Google SQL Interview Problem | Solving SQL Int...     2022-10-10   33977
# 21  SQL Interview Problem asked by Product Based C...     2022-10-05   55291
# 22              How to become a Data Analyst FASTER ?     2022-09-30   95048
# 23  Tricky SQL Interview Query | Practice Solving ...     2022-09-22   28362
# 24  Solving SQL Interview Query using a "VERY IMPO...     2022-09-19   96196
# 25  Solving SQL Interview Query | SQL Problem by S...     2022-09-16   29565
# 26  Practice SQL Interview Query | Big 4 Interview...     2022-09-12   82124
# 27  Solving SQL Interview Query | Ungroup given in...     2022-09-08   35009
# 28  How to remove Duplicate Data in SQL | SQL Quer...     2022-09-02  226084
# 29  Solving Complex SQL Query from HackerRank | SQ...     2022-08-10   59899
# 30  Data Analyst vs Business Analyst | What should...     2022-07-26   27297
# 31  Materialized View in SQL | Faster SQL Queries ...     2022-07-07   62231
# 32  Learn SQL the right way | SQL Live Training | ...     2022-06-28   30086
# 33  SQL Interview Assignment Queries | REAL SQL As...     2022-06-21   23091
# 34  SQL Interview Assignment Queries | REAL SQL As...     2022-06-17   18990
# 35  REAL SQL Interview Question | Complex SQL Inte...     2022-06-03   56798
# 36  Top 10 Tips for JOB Interview | Tips for Job I...     2022-05-25   14657
# 37          Solving SQL Query | Rows to Column in SQL     2022-05-18  116169
# 38  Procedure Tutorial in SQL | SQL Stored Procedu...     2022-05-01  169932
# 39            my Live SQL Course Announcement #shorts     2022-04-05   20000
# 40  Best Online SQL Course to practically learn an...     2022-03-30   29502
# 41  Recursive SQL Queries Tutorial | Learn to writ...     2022-03-23  130249
# 42  Solving SQL Interview Queries | Tricky SQL Int...     2022-03-16  204215
# 43  How to learn SQL | Step by Step Guide on how t...     2022-03-02  129614
# 44  ANSI vs Non ANSI Joins in SQL | SQL Query Writ...     2022-02-23   30592
# 45  SQL Views Tutorial | VIEWS in SQL Complete Tut...     2022-02-15  173998
# 46  Practice Writing SQL Queries on StrataScratch ...     2022-02-08  129888
# 47  Subquery in SQL | Correlated Subquery + Comple...     2022-02-01  704494
# 48  SQL JOINS Tutorial for beginners | Practice SQ...     2022-01-14  210389
# 49  SQL JOINS Tutorial for beginners | Practice SQ...     2022-01-06  587569
#
#     Likes Comments  Dislikes
# 0     353       63         0
# 1    1074      109         0
# 2     154       28         0
# 3     237       33         0
# 4     347       45         0
# 5    1501      132         0
# 6     622      179         0
# 7     268       23         0
# 8    1023      105         0
# 9     770       63         0
# 10   2577      243         0
# 11    250      154         0
# 12  13079      399         0
# 13   1473       18         0
# 14    889       52         0
# 15   9467      270         0
# 16   1525      123         0
# 17   1774       68         0
# 18    988       76         0
# 19   7768      385         0
# 20   1276      128         0
# 21   2109      135         0
# 22   4020      190         0
# 23    869       99         0
# 24   2343      177         0
# 25   1101       73         0
# 26   3011      172         0
# 27   1049       81         0
# 28   5568      234         0
# 29   1519      144         0
# 30   1202      110         0
# 31   1681      171         0
# 32    590      189         0
# 33    570       49         0
# 34    569       80         0
# 35   1397      112         0
# 36    574       45         0
# 37   3044      160         0
# 38   3358      180         0
# 39    872       85         0
# 40    548      118         0
# 41   3429      250         0
# 42   5213      407         0
# 43   4622      340         0
# 44    682       84         0
# 45   3868      334         0
# 46   3311      187         0
# 47  16387      995         0
# 48   6956      494         0
# 49  14362      933         0

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                 Title Published_date   Views  \
# 0     Courses You Can Take To Get Into Data Analytics     2023-09-02   15274
# 1   Solving a Real SQL Interview Problem | Job Vac...     2023-08-25   27759
# 2   Python Bootcamp for Beginners | Python Course ...     2023-08-20    3797
# 3   SQL Data Analytics Project (PART 3) | Data Ana...     2023-08-19    6925
# 4   SQL Data Analytics Project (PART 2) | Data Ana...     2023-08-06   11067
# 5   SQL Data Analytics Project (PART 1) | Data Ana...     2023-08-04   42431
# 6   Learn SQL from me | Live SQL Training | SQL Bo...     2023-05-25   22223
# 7   Learn Python here | Learn Python Programming here     2023-05-16   14530
# 8   Solving a Complex SQL Interview problem | Prac...     2023-03-21   36489
# 9   REAL SQL Interview Problem | Hierarchical data...     2023-03-14   20144
# 10    Complete guide to Database Normalization in SQL     2023-03-07   57580
# 11  SQL Live class on Lighthall | Learn SQL from B...     2023-01-26   12439
# 12  How to learn SQL for free | Roadmap to learnin...     2022-12-28  423502
# 13                   Solving an SQL Interview Problem     2022-12-18   36374
# 14  Solving SQL Interview Query | Find Tree Node t...     2022-12-12   20732
# 15  Solving SQL Interview Query for Data Analyst a...     2022-12-07  409381
# 16               Solving a tricky SQL Interview Query     2022-11-21   44314
# 17               SQL Interview Query for Data Analyst     2022-11-14   49276
# 18  Solving a Complex SQL Interview Problem | Find...     2022-10-31   25597
# 19  SQL JOINS Interview Question | What does diffe...     2022-10-24  250474
# 20  Google SQL Interview Problem | Solving SQL Int...     2022-10-10   33977
# 21  SQL Interview Problem asked by Product Based C...     2022-10-05   55291
# 22              How to become a Data Analyst FASTER ?     2022-09-30   95048
# 23  Tricky SQL Interview Query | Practice Solving ...     2022-09-22   28362
# 24  Solving SQL Interview Query using a "VERY IMPO...     2022-09-19   96196
# 25  Solving SQL Interview Query | SQL Problem by S...     2022-09-16   29565
# 26  Practice SQL Interview Query | Big 4 Interview...     2022-09-12   82124
# 27  Solving SQL Interview Query | Ungroup given in...     2022-09-08   35009
# 28  How to remove Duplicate Data in SQL | SQL Quer...     2022-09-02  226084
# 29  Solving Complex SQL Query from HackerRank | SQ...     2022-08-10   59899
# 30  Data Analyst vs Business Analyst | What should...     2022-07-26   27297
# 31  Materialized View in SQL | Faster SQL Queries ...     2022-07-07   62231
# 32  Learn SQL the right way | SQL Live Training | ...     2022-06-28   30086
# 33  SQL Interview Assignment Queries | REAL SQL As...     2022-06-21   23091
# 34  SQL Interview Assignment Queries | REAL SQL As...     2022-06-17   18990
# 35  REAL SQL Interview Question | Complex SQL Inte...     2022-06-03   56798
# 36  Top 10 Tips for JOB Interview | Tips for Job I...     2022-05-25   14657
# 37          Solving SQL Query | Rows to Column in SQL     2022-05-18  116169
# 38  Procedure Tutorial in SQL | SQL Stored Procedu...     2022-05-01  169932
# 39            my Live SQL Course Announcement #shorts     2022-04-05   20000
# 40  Best Online SQL Course to practically learn an...     2022-03-30   29502
# 41  Recursive SQL Queries Tutorial | Learn to writ...     2022-03-23  130249
# 42  Solving SQL Interview Queries | Tricky SQL Int...     2022-03-16  204215
# 43  How to learn SQL | Step by Step Guide on how t...     2022-03-02  129614
# 44  ANSI vs Non ANSI Joins in SQL | SQL Query Writ...     2022-02-23   30592
# 45  SQL Views Tutorial | VIEWS in SQL Complete Tut...     2022-02-15  173998
# 46  Practice Writing SQL Queries on StrataScratch ...     2022-02-08  129888
# 47  Subquery in SQL | Correlated Subquery + Comple...     2022-02-01  704494
# 48  SQL JOINS Tutorial for beginners | Practice SQ...     2022-01-14  210389
# 49  SQL JOINS Tutorial for beginners | Practice SQ...     2022-01-06  587569
#
#     Likes Comments  Dislikes Month
# 0     353       63         0   Sep
# 1    1074      109         0   Aug
# 2     154       28         0   Aug
# 3     237       33         0   Aug
# 4     347       45         0   Aug
# 5    1501      132         0   Aug
# 6     622      179         0   May
# 7     268       23         0   May
# 8    1023      105         0   Mar
# 9     770       63         0   Mar
# 10   2577      243         0   Mar
# 11    250      154         0   Jan
# 12  13079      399         0   Dec
# 13   1473       18         0   Dec
# 14    889       52         0   Dec
# 15   9467      270         0   Dec
# 16   1525      123         0   Nov
# 17   1774       68         0   Nov
# 18    988       76         0   Oct
# 19   7768      385         0   Oct
# 20   1276      128         0   Oct
# 21   2109      135         0   Oct
# 22   4020      190         0   Sep
# 23    869       99         0   Sep
# 24   2343      177         0   Sep
# 25   1101       73         0   Sep
# 26   3011      172         0   Sep
# 27   1049       81         0   Sep
# 28   5568      234         0   Sep
# 29   1519      144         0   Aug
# 30   1202      110         0   Jul
# 31   1681      171         0   Jul
# 32    590      189         0   Jun
# 33    570       49         0   Jun
# 34    569       80         0   Jun
# 35   1397      112         0   Jun
# 36    574       45         0   May
# 37   3044      160         0   May
# 38   3358      180         0   May
# 39    872       85         0   Apr
# 40    548      118         0   Mar
# 41   3429      250         0   Mar
# 42   5213      407         0   Mar
# 43   4622      340         0   Mar
# 44    682       84         0   Feb
# 45   3868      334         0   Feb
# 46   3311      187         0   Feb
# 47  16387      995         0   Feb
# 48   6956      494         0   Jan
# 49  14362      933         0   Jan

# %%
videos_per_month = video_data.groupby('Month',as_index = False).size()

# %%
videos_per_month
# Out:
#    Month  size
# 0    Apr     1
# 1    Aug     6
# 2    Dec     4
# 3    Feb     4
# 4    Jan     3
# 5    Jul     2
# 6    Jun     4
# 7    Mar     7
# 8    May     5
# 9    Nov     2
# 10   Oct     4
# 11   Sep     8

# %%
sort_order = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'],categories = sort_order,ordered = True)

# %%
videos_per_month = videos_per_month.sort_index()

# %%
videos_per_month
# Out:
#       Month  size
# Month
# Jan     Jan     3
# Feb     Feb     4
# Mar     Mar     7
# Apr     Apr     1
# May     May     5
# Jun     Jun     4
# Jul     Jul     2
# Aug     Aug     6
# Sep     Sep     8
# Oct     Oct     4
# Nov     Nov     2
# Dec     Dec     4

# %%
ax2 = sns.barplot(x = 'Month', y = 'size' , data = videos_per_month)
# Out:
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aryan\Desktop\YT-DataAnalysis\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
video_data.to_csv('Yt_channels_analysis.csv')
